# %%
import pandas as pd

# %%
snrDict=dict.fromkeys(['l','BW','ThreshSNRReq10Tap_Low'])

# %%
snrDict['l'] = [e for e in [350,360,385,412,425,443,460,475,490,510,532,555,583,617,
                                       640,655,665,678,710,748,820,865]]

# %%
bwlst= 14*[15] + [10] + [15] + 2*[10] + [15] + [10] + [15] + [40]
snrDict['BW'] = [e for e in bwlst ]

# %%
snrlst=[300] + 8 * [1000] + [950] + [850] + [700] + [450] + [650] + [550] + [650] + 2* [900] + [800] + [350] + [150] +[300]
snrDict['ThreshSNRReq10Tap_Low'] = [e for e in snrlst]

# %%
df = pd.DataFrame(snrDict)

# %%
df.set_index('l',inplace=True)

# %%
df
# Out:
#      BW  ThreshSNRReq10Tap_Low
# l
# 350  15                    300
# 360  15                   1000
# 385  15                   1000
# 412  15                   1000
# 425  15                   1000
# 443  15                   1000
# 460  15                   1000
# 475  15                   1000
# 490  15                   1000
# 510  15                    950
# 532  15                    850
# 555  15                    700
# 583  15                    450
# 617  15                    650
# 640  10                    550
# 655  15                    650
# 665  10                    900
# 678  10                    900
# 710  15                    800
# 748  10                    350
# 820  15                    150
# 865  40                    300

# %%
df.to_pickle('/disk01/home/ekarakoy/UNCERTAINTIES/datafiles/SNRReq160727.pkl')

# %%
import pickle

# %%
# Let's add this new table to the old one
dfGsdSnr = pickle.load(open('/disk01/home/ekarakoy/UNCERTAINTIES/datafiles/GSDSND_pandasDF.p','rb'))

# %%
dfGsdSnr
# Out:
#       BW   Ltyp  Lmax   Req  Req*1.2     Baseline          ID2          ID3  \
# l
# 350   15  7.460  35.6   300      360  1278.755498   909.781056  1094.505850
# 360   15  7.220  37.6  1000     1200  1381.347867   981.086454  1189.252725
# 385   15  6.110  38.1  1000     1200  1569.818945  1111.746489  1365.096756
# 412   15  7.860  60.2  1000     1200  2243.816457  1576.589636  2008.275703
# 425   15  6.950  58.5  1000     1200  2111.332319  1485.432249  1880.454684
# 443   15  7.020  66.4  1000     1200  2153.047370  1514.143315  1920.641610
# 460   15  6.830  72.4  1000     1200  2066.373434  1454.479058  1837.208262
# 475   15  6.190  72.2  1000     1200  1962.036155  1382.603633  1737.124772
# 490   15  5.310  68.6  1000     1200  1779.627075  1256.783971  1563.202565
# 510   15  4.580  66.3  1000     1200  1620.424103  1146.765176  1412.668406
# 532   15  3.920  65.1  1000     1200  1440.715306  1022.287342  1244.404561
# ...

# %%
newframe=dfGsdSnr.copy()

# %%
newframe['ThreshSNRReq10Tap_Low'] = df['ThreshSNRReq10Tap_Low']

# %%
newframe
# Out:
#       BW   Ltyp  Lmax   Req  Req*1.2     Baseline          ID2          ID3  \
# l
# 350   15  7.460  35.6   300      360  1278.755498   909.781056  1094.505850
# 360   15  7.220  37.6  1000     1200  1381.347867   981.086454  1189.252725
# 385   15  6.110  38.1  1000     1200  1569.818945  1111.746489  1365.096756
# 412   15  7.860  60.2  1000     1200  2243.816457  1576.589636  2008.275703
# 425   15  6.950  58.5  1000     1200  2111.332319  1485.432249  1880.454684
# 443   15  7.020  66.4  1000     1200  2153.047370  1514.143315  1920.641610
# 460   15  6.830  72.4  1000     1200  2066.373434  1454.479058  1837.208262
# 475   15  6.190  72.2  1000     1200  1962.036155  1382.603633  1737.124772
# 490   15  5.310  68.6  1000     1200  1779.627075  1256.783971  1563.202565
# 510   15  4.580  66.3  1000     1200  1620.424103  1146.765176  1412.668406
# 532   15  3.920  65.1  1000     1200  1440.715306  1022.287342  1244.404561
# ...

# %%
newframe.to_pickle('/disk01/home/ekarakoy/UNCERTAINTIES/datafiles/GSDSND_pandasDF.p')

# %%
dfGsdSnr.index
# Out:
# Int64Index([ 350,  360,  385,  412,  425,  443,  460,  475,  490,  510,  532,
#              555,  583,  617,  640,  655,  665,  678,  710,  748,  820,  865,
#              940, 1240, 1380, 1640, 2130, 2250],
#            dtype='int64', name='l')

# %%
dfGsdSnr.ID8
# Out:
# l
# 350     1414.529507
# 360     1534.517728
# 385     1756.537433
# 412     2562.995721
# 425     2403.282981
# 443     2453.521154
# 460     2349.193500
# 475     2223.903811
# 490     2005.762870
# 510     1816.465616
# 532     1604.241591
# 555     1412.138754
# 583     1480.892137
# 617     1455.559753
# 640     1152.063791
# 655     1340.431415
# 665     1079.636854
# 678     1028.304065
# 710     1147.235667
# 748      790.739306
# 820      654.391981
# 865      770.285770
# 940      278.234952
# 1240     189.733938
# 1380     164.225935
# 1640     127.433012
# 2130      26.161444
# 2250     201.864564
# Name: ID8, dtype: float64
