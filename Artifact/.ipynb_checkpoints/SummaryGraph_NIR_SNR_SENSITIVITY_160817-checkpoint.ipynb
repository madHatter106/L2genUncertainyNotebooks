# %%
import pandas as pd
import pickle
import matplotlib.pyplot as pl
import numpy as np
import os
from matplotlib.pylab import rcParams
rcParams['xtick.labelsize'] = 14
rcParams['ytick.labelsize'] = 14
% matplotlib notebook

# %%
mainDir = '/accounts/ekarakoy/UNCERTAINTIES/datafiles/BiasError/'
Rho95tileDictPath = os.path.join(mainDir, 'rho95TtilDict.p')
rho95tileDict = pickle.load(open(Rho95tileDictPath, 'rb'))
Xfor95_path = os.path.join(mainDir, 'XBiasFor95.p')
Xfor95Dict = pickle.load(open(Xfor95_path, 'rb'))

# %%
df_xFor95 = pd.DataFrame(Xfor95Dict,dtype='float')

# %%
df_xFor95
# Out:
#      NIR_SNR_500  NIR_SNR_550  NIR_SNR_600  NIR_SNR_650  NIR_SNR_700  \
# 412     0.000000     0.000000     0.082125     0.156938     0.196582
# 443     0.194629     0.264453     0.307422     0.337109     0.358594
# 490     0.517969     0.552246     0.576855     0.595313     0.609668
# 510     0.659326     0.689429     0.711548     0.728467     0.741357
# 555     1.049512     1.072656     1.090039     1.103516     1.114063
# 670     2.103027     2.110645     2.116309     2.120801     2.124121
#
#      NIR_SNR_750  NIR_SNR_800
# 412     0.223535     0.242969
# 443     0.374805     0.387793
# 490     0.620801     0.629883
# 510     0.751538     0.759814
# 555     1.122754     1.129700
# 670     2.127173     2.129535

# %%
df_xFor95.to_excel(os.path.join(mainDir,'xFor95inPerc.xlsx'))

# %%
# PLOTTING NIR_SNR w/ BIAS SENSITIVITY RESULTS

# %%
pnRho95 = pd.Panel(rho95tileDict)

# %%
pnRho95
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 7 (items) x 6 (major_axis) x 6 (minor_axis)
# Items axis: NIR_SNR_500 to NIR_SNR_800
# Major_axis axis: 0 to 0.020
# Minor_axis axis: 412 to 670

# %%
pnRho95ByExp = pnRho95.swapaxes('items','major_axis')

# %%
pnRho95ByExp = pnRho95ByExp.swapaxes('major_axis','minor_axis')
pnRho95ByExp
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 6 (items) x 6 (major_axis) x 7 (minor_axis)
# Items axis: 0 to 0.020
# Major_axis axis: 412 to 670
# Minor_axis axis: NIR_SNR_500 to NIR_SNR_800

# %%
pnRho95Swap = pnRho95.swapaxes('major_axis','minor_axis')

# %%
pnRho95Swap
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 7 (items) x 6 (major_axis) x 6 (minor_axis)
# Items axis: NIR_SNR_500 to NIR_SNR_800
# Major_axis axis: 412 to 670
# Minor_axis axis: 0 to 0.020

# %%
pnRho95Swap.to_pickle(os.path.join(mainDir,'rho95tilePanel.p'))

# %%
simsList = pnRho95.items.tolist()
print(simsList)
# Out:
# ['NIR_SNR_500', 'NIR_SNR_550', 'NIR_SNR_600', 'NIR_SNR_650', 'NIR_SNR_700', 'NIR_SNR_750', 'NIR_SNR_800']

# %%
def PlotSummaryGraphByError(df,simName,**kwargs):
    colors= ['black','blue','m','c','orange','r']
    title =  "%s 95%%tiles" % simName
    savepath = kwargs.pop('savepath',None)
    f,ax=pl.subplots(figsize=(12,7))
    axYmaxBase = 0.002
    axYmax = kwargs.pop('ymax',axYmaxBase)
    axInYmax = 2.1e-4
    ax.set_ylim(0,axYmax)
    gboxY = 8e-5 / axYmax
    gboxY2 = 8e-5 / axInYmax
    ymaxScl = axYmaxBase / axYmax
    ax.set_xlim(412,710)
    ax.set_xticks([412,443,490,510,555,670])
    if title:
        ax.set_title(title,fontsize=22)
    ax.set_ylabel(r'uncertainty ($\rho$)',fontsize=17)
    ax.set_xlabel(r'$\lambda$',fontsize=18)
    ax.axvspan(412,600,ymin=0,ymax=.5*ymaxScl,facecolor='gray',alpha=0.1)
    ax.axvspan(412,600,ymax=.4*ymaxScl,
               facecolor='gray',alpha=0.3)
    ax.axvspan(600,700,ymax=1 * ymaxScl,
               facecolor='gray',alpha=0.1,label='threshold')
    ax.axvspan(600,700,ymax=.8 * ymaxScl,facecolor='gray',alpha=0.3,label='20% margin')
    ax.axvspan(650,700,ymax=gboxY,facecolor='gold',alpha=0.4,label='nflh ROI')
    errList = df.columns.tolist()
    for err,col in zip(errList,colors):
        lerr = float(err) * 100
        lbl = r'bias (%%$\rho_t$) : %.1f' % lerr
        ax.plot(df[err],label=lbl,marker='o',color=col,lw=1.5)
    ax.ticklabel_format(style='sci',axis='y',scilimits=(-2,3))
    ax.legend(loc='right',bbox_to_anchor=(1.05,.75));
    if savepath:
        savename = 'stats_%s.png' % simName
        savepath = os.path.join(savepath,savename)
        f.savefig(savepath,dpi=300,format='png')

# %%
spath = '/accounts/ekarakoy/UNCERTAINTIES/figs/ArtifactNoise/'

# %%
simName = 'NIR_SNR_500'
PlotSummaryGraph(pnRho95Swap[simName],simName,savepath=spath)
# Out:
# <img src="data:image/png;base64,...">

# %%
simName = 'NIR_SNR_550'
PlotSummaryGraph(pnRho95Swap[simName],simName,savepath=spath)
# Out:
# <img src="data:image/png;base64,...">

# %%
simName = 'NIR_SNR_600'
PlotSummaryGraph(pnRho95Swap[simName],simName,ymax=2e-3,savepath=spath)
# Out:
# <img src="data:image/png;base64,...">

# %%
simName = 'NIR_SNR_650'
PlotSummaryGraph(pnRho95Swap[simName],simName,ymax=2e-3,savepath=spath)
# Out:
# <img src="data:image/png;base64,...">

# %%
simName = 'NIR_SNR_700'
PlotSummaryGraph(pnRho95Swap[simName],simName,ymax=2e-3,savepath=spath)
# Out:
# <img src="data:image/png;base64,...">

# %%
simName = 'NIR_SNR_750'
PlotSummaryGraph(pnRho95Swap[simName],simName,ymax=2e-3,savepath=spath)
# Out:
# <img src="data:image/png;base64,...">

# %%
simName = 'NIR_SNR_800'
PlotSummaryGraph(pnRho95Swap[simName],simName,ymax=2e-3,savepath=spath)
# Out:
# <img src="data:image/png;base64,...">

# %%
def PlotSummaryGraphByExp(df,simName,**kwargs):
    colors= ['black','brown','blue','m','c','orange','r']
    title =  "%.1f%% Error - 95%%tiles" % (float(simName) * 100)
    savepath = kwargs.pop('savepath',None)
    f,ax=pl.subplots(figsize=(12,7))
    axYmaxBase = 0.002
    axYmax = kwargs.pop('ymax',axYmaxBase)
    axInYmax = 2.1e-4
    ax.set_ylim(0,axYmax)
    gboxY = 8e-5 / axYmax
    gboxY2 = 8e-5 / axInYmax
    ymaxScl = axYmaxBase / axYmax
    ax.set_xlim(412,710)
    ax.set_xticks([412,443,490,510,555,670])
    if title:
        ax.set_title(title,fontsize=22)
    ax.set_ylabel(r'uncertainty ($\rho$)',fontsize=17)
    ax.set_xlabel(r'$\lambda$',fontsize=18)
    ax.axvspan(412,600,ymin=0,ymax=.5*ymaxScl,facecolor='gray',alpha=0.1)
    ax.axvspan(412,600,ymax=.4*ymaxScl,
               facecolor='gray',alpha=0.3)
    ax.axvspan(600,700,ymax=1 * ymaxScl,
               facecolor='gray',alpha=0.1,label='threshold')
    ax.axvspan(600,700,ymax=.8 * ymaxScl,facecolor='gray',alpha=0.3,label='20% margin')
    ax.axvspan(650,700,ymax=gboxY,facecolor='gold',alpha=0.4,label='nflh ROI')
    expList = df.columns.tolist()
    for exp,col in zip(expList,colors): 
        lbl = r'bias (%%$\rho_t$) : %s' % exp
        ax.plot(df[exp],label=lbl,marker='o',color=col,lw=1.5)
    ax.ticklabel_format(style='sci',axis='y',scilimits=(-2,3))
    ax.legend(loc='right',bbox_to_anchor=(1.05,.75));
    if savepath:
        savename = 'stats_%sPercError.png' % simName
        savepath = os.path.join(savepath,savename)
        f.savefig(savepath,dpi=300,format='png')

# %%
title =  "%.1f 95%%tiles" % (float(simName) * 100)
print(title)
# Out:
# 0.2 95%tiles

# %%
pnRho95ByExp['0.002']
# Out:
#      NIR_SNR_500  NIR_SNR_550  NIR_SNR_600  NIR_SNR_650  NIR_SNR_700  \
# 412     0.001215     0.001146     0.001090     0.001043     0.001004
# 443     0.001004     0.000944     0.000895     0.000854     0.000819
# 490     0.000762     0.000713     0.000673     0.000639     0.000611
# 510     0.000683     0.000637     0.000599     0.000567     0.000541
# 555     0.000526     0.000489     0.000459     0.000434     0.000413
# 670     0.000250     0.000233     0.000219     0.000207     0.000197
#
#      NIR_SNR_750  NIR_SNR_800
# 412     0.000971     0.000943
# 443     0.000790     0.000765
# 490     0.000587     0.000566
# 510     0.000518     0.000499
# 555     0.000395     0.000380
# 670     0.000189     0.000182

# %%
simName = '0.002'
PlotSummaryGraphByExp(pnRho95ByExp[simName],simName,savepath=spath)
# Out:
# <img src="data:image/png;base64,...">

# %%
simName = '0'
PlotSummaryGraphByExp(pnRho95ByExp[simName],simName,savepath=spath)
# Out:
# <img src="data:image/png;base64,...">
